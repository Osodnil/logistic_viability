# %% [markdown]
# # Demo Viabilidade Logística
# Notebook de demonstração para execução do pipeline.

# %%
from cd_viabilidade.cli import run_pipeline
from cd_viabilidade.config import AppConfig
run_pipeline(AppConfig())
